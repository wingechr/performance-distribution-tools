# %%
import pandas as pd

# %%
df = pd.read_csv('output/test.csv')

# %%
df
# Out:
#          1990      1991      1992      1993      1994      1995      1996  \
# 0    0.004012  0.004114  0.004025  0.003715  0.003475  0.003302  0.003224
# 1    0.011018  0.010920  0.012424  0.008107  0.009397  0.009057  0.007875
# 2    0.081446  0.039413  0.024996  0.025154  0.030603  0.025535  0.025631
# 3    0.840248  0.870564  0.884801  0.865110  1.008988  1.115317  1.056271
# 4    0.044491  0.052940  0.059342  0.065032  0.070982  0.060263  0.055055
# ..        ...       ...       ...       ...       ...       ...       ...
# 130  0.018532  0.022629  0.028110  0.029685  0.032928  0.036096  0.045395
# 131  0.034930  0.028365  0.030257  0.034472  0.029080  0.033561  0.029763
# 132  0.076295  0.069458  0.064290  0.065685  0.073726  0.075593  0.089487
# 133  0.023006  0.019423  0.017450  0.017143  0.013353  0.013884  0.015649
# 134  0.037908  0.037850  0.032322  0.031190  0.023438  0.035862  0.036391
#
#          1997      1998      1999  ...      2011      2012      2013  \
# ...

# %%
df_perc_change = df.pct_change(axis='columns') * 100

# %%
df_perc_change
# Out:
#      1990       1991       1992       1993       1994       1995       1996  \
# 0     NaN   2.549610  -2.172645  -7.693016  -6.467459  -4.983606  -2.359112
# 1     NaN  -0.880827  13.764134 -34.744786  15.916279  -3.623464 -13.053853
# 2     NaN -51.608299 -36.578512   0.631865  21.661048 -16.560343   0.376215
# 3     NaN   3.607964   1.635380  -2.225467  16.631288  10.538089  -5.294062
# 4     NaN  18.991531  12.093261   9.588627   9.149021 -15.101403  -8.642123
# ..    ...        ...        ...        ...        ...        ...        ...
# 130   NaN  22.108317  24.221866   5.602601  10.927078   9.621716  25.761084
# 131   NaN -18.795586   6.672405  13.930332 -15.642886  15.408097 -11.316083
# 132   NaN  -8.960201  -7.441522   2.171017  12.240434   2.532455  18.379861
# 133   NaN -15.573742 -10.159270  -1.757400 -22.107634   3.976838  12.711928
# 134   NaN  -0.153594 -14.604884  -3.501801 -24.854464  53.008753   1.475800
#
# ...

# %%
((-1.166280) + (-1.163889) + (-39.976831) + 73.723002 + 40.878309)/5
# Out:
# 14.458862199999999

# %%
((-1.163889) + (-39.976831) + 73.723002 + 40.878309 + (-22.835698))/5
# Out:
# 10.124978599999999

# %%
df_rolling_average = df_perc_change.rolling(window=5, axis='columns').mean()

# %%
df_rolling_average
# Out:
#      1990  1991  1992  1993  1994       1995       1996       1997       1998  \
# 0     NaN   NaN   NaN   NaN   NaN  -3.753423  -4.735167  -4.635174  -3.333960
# 1     NaN   NaN   NaN   NaN   NaN  -1.913733  -4.348338  -5.562199   3.849914
# 2     NaN   NaN   NaN   NaN   NaN -16.490848  -6.093946  -3.758490 -12.669951
# 3     NaN   NaN   NaN   NaN   NaN   6.037451   4.257046   0.265975   5.820256
# 4     NaN   NaN   NaN   NaN   NaN   6.944208   1.417477   5.277116   3.579805
# ..    ...   ...   ...   ...   ...        ...        ...        ...        ...
# 130   NaN   NaN   NaN   NaN   NaN  14.496315  15.226869  14.615549  17.660159
# 131   NaN   NaN   NaN   NaN   NaN   0.314472   1.810373   3.373080  -0.959112
# 132   NaN   NaN   NaN   NaN   NaN   0.108437   5.576449   7.759892   5.389806
# 133   NaN   NaN   NaN   NaN   NaN  -9.124242  -3.467108  -0.010374  -1.918254
# 134   NaN   NaN   NaN   NaN   NaN   1.978802   2.304681   6.962264   7.455531
#
# ...

# %%
series = df_rolling_average[str('2019')]

# %%
series
# Out:
# 0      10.124978
# 1       0.199770
# 2       0.460567
# 3       5.606237
# 4       3.652684
#          ...
# 130     9.951860
# 131    -8.448676
# 132     7.110184
# 133     9.123356
# 134    10.088241
# Name: 2019, Length: 135, dtype: float64
